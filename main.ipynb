# %%
# If running in colab or a new environment, you can install directly from git:
# !pip install git+https://github.com/C0ll1nDr4k3/concurrency-benchmarks.git

import nilvec

print(nilvec.__file__)
print(dir(nilvec))

from nilvec.benchmark import (
    run_benchmark,
    load_dataset,
    benchmark_throughput_vs_threads,
    ICON_MAPPING,
    COLOR_MAPPING
)

print("Imported nilvec successfully!")
# Out:
# ...
#   Cloning https://github.com/C0ll1nDr4k3/concurrency-benchmarks.git to /tmp/pip-req-build-7ghut9js
#   Running command git clone --filter=blob:none --quiet https://github.com/C0ll1nDr4k3/concurrency-benchmarks.git /tmp/pip-req-build-7ghut9js
#   Resolved https://github.com/C0ll1nDr4k3/concurrency-benchmarks.git to commit 7b35080e4e2e8da007c336d0aa36eb8aea0c7aab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# /usr/local/lib/python3.12/dist-packages/nilvec.cpython-312-x86_64-linux-gnu.so
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1182779820.py in <cell line: 0>()
#       4 import nilvec
#       5 print(nilvec.__file__)
# ----> 6 from nilvec.benchmark import (
#       7     run_benchmark,
#       8     load_dataset,
# ...

# %%
# Example of running a quick benchmark using the library
class Args:
    dataset = "fashion-mnist-784-euclidean.hdf5"
    skip_recall = True
    skip_throughput = False
    rw_ratio = 0.5
    save_results = "nb_results.pkl"
    only_external = False

run_benchmark(Args())
